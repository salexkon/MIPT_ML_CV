# %% [markdown]
# # Обучение нейросетей: Базовые приемы

# %%
# !unzip -qo dataset.zip

# %%
import glob

import matplotlib.pyplot as plt
import numpy as np
import PIL.Image
import torch
import torch.nn.functional as F
from torch import nn
from tqdm import tqdm

# Increase these if figures appear small
plt.rcParams["figure.figsize"] = fx, fy = (14.08, 6.40)

# %%
def show_images(images, titles=[]):
    num = len(images)
    fig, axs = plt.subplots(nrows=1, ncols=num, squeeze=True, layout="constrained")
    axs = [axs] if num <= 1 else axs
    for i in range(num):
        ax = axs[i]
        ax.imshow(images[i])
        ax.axis("off")
        if titles != []:
            ax.set_title(titles[i])

    plt.show(fig)
    plt.close(fig)

# %% [markdown]
# ## Обучение простого классификатора на PyTorch

# %%
CLASSES = {"cloudy": 0, "foggy": 1, "rainy": 2, "shine": 3, "sunrise": 4}

# %%
weather_images = []
titles = []
for weather in CLASSES.keys():
    sample = sorted(glob.glob(f"./dataset/{weather}/*")).pop(0)
    weather_images.append(PIL.Image.open(sample))
    titles.append(weather)
show_images(weather_images, titles)

# %% [markdown]
# Научимся использовать свои данные при обучении, для этого необхимо создать свой собственный подкласс **`torch.utils.data.Dataset`**.
#
# Также для подтверждения успешности обучения модели понадобится валидационная выборка, которая не должна пересекаться с обучающей.

# %%
NETWORK_SIZE = (64, 64)
BATCH_SIZE = 16

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print("Using the GPU 😊")
elif torch.mps.is_available():
    DEVICE = torch.device("mps")
    print("Using MPS")
else:
    DEVICE = torch.device("cpu")
    print("Using the CPU 😞")
# Out:
# Using the CPU 😞

# %%
import torchvision.transforms.v2 as T

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]
DEFAULT_TRANSFORM = T.Compose(
    [
        T.ToImage(),
        T.ToDtype(torch.float32, scale=True),
        T.Resize(size=NETWORK_SIZE),
        T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
    ]
)

# %%
import random

from torch.utils import data


class MyCustomDataset(data.Dataset):
    def __init__(
        self,
        mode,
        root_dir="./dataset",
        train_fraction=0.8,
        split_seed=42,
        transform=None,
    ):
        # We can't store all the images in memory at the same time,
        # because sometimes we have to work with very large datasets
        # so we will only store data paths.

        paths = []
        labels = []
        rng = random.Random(split_seed)
        for cls_name, cls_idx in CLASSES.items():

            # Make sure that train and validation splits
            # use the same (random) order of samples
            cls_paths = sorted(glob.glob(f"{root_dir}/{cls_name}/*"))
            split = int(train_fraction * len(cls_paths))
            rng.shuffle(cls_paths)

            if mode == "train":
                cls_paths = cls_paths[:split]
            elif mode == "valid":
                cls_paths = cls_paths[split:]
            else:
                raise RuntimeError(f"Invalid mode: {mode!r}")

            paths.extend(cls_paths)
            labels.extend(cls_idx for _ in range(len(cls_paths)))

        self._len = len(paths)
        self._paths = paths
        self._labels = np.array(labels)
        assert self._labels.shape == (self._len,)

        if transform is None:
            transform = DEFAULT_TRANSFORM
        self._transform = transform

    def __len__(self):
        return len(self._paths)

    def __getitem__(self, index):
        img_path = self._paths[index]
        label = self._labels[index]

        # Read the image from disk
        image = np.array(PIL.Image.open(img_path).convert("RGB"))

        # Apply the desired transformations
        image = self._transform(image)

        return image, label

# %%
import os
# use num_workers=os.cpu_count() if available
# Prepare the data
ds_train = MyCustomDataset(mode="train")
ds_valid = MyCustomDataset(mode="valid")

dl_train = data.DataLoader(
    ds_train,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    num_workers=0,
)
dl_valid = data.DataLoader(
    ds_valid,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    num_workers=0,
)

# %% [markdown]
# Будем использовать простую сверточную архитектуру

# %%
class MyModel(nn.Sequential):
    def __init__(self, num_classes):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2)

        self.conv2 = nn.Conv2d(6, 16, kernel_size=3)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2)

        self.conv3 = nn.Conv2d(16, 5, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2)

        # (N, 5, 7, 7) -> (N, 5 * 7 * 7 == 245)
        self.flatten = nn.Flatten(start_dim=1, end_dim=-1)

        self.fc1 = nn.Linear(5 * 7 * 7, 120)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(120, 84)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(84, num_classes)

# %% [markdown]
# ## Обучение на PyTorch

# %%
def train(num_epochs):
    # Prepare model and optimization stuff
    model = MyModel(num_classes=len(CLASSES)).to(DEVICE)
    loss_fn = torch.nn.CrossEntropyLoss().to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    # The main loop
    for e in range(num_epochs):

        # Train for a single epoch
        model = model.train()
        train_loss = []
        progress_train = tqdm(
            total=len(dl_train),
            desc=f"Epoch {e}",
            leave=False,
        )
        for x_batch, y_batch in dl_train:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)

            p_batch = model(x_batch)
            loss = loss_fn(p_batch, y_batch)
            train_loss.append(loss.detach())

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            progress_train.update()
        progress_train.close()

        train_loss = torch.stack(train_loss).mean()
        print(
            f"Epoch {e},",
            f"train_loss: {train_loss.item():.8f}",
        )

        # Measure metrics on validation
        model = model.eval()
        valid_accs = []
        progress_valid = tqdm(
            total=len(dl_valid),
            desc=f"Epoch {e}",
            leave=False,
        )
        for x_batch, y_batch in dl_valid:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)

            with torch.no_grad():
                p_batch = model(x_batch)

            matches = p_batch.argmax(axis=-1) == y_batch
            valid_accs.append(matches)

            progress_valid.update()
        progress_valid.close()

        valid_accs = torch.concat(valid_accs).float().mean()
        print(
            f"Epoch {e},",
            f"valid_accs: {valid_accs.item():.8f}",
        )

    return model

# %% [markdown]
# ## Learning

# %%
model = train(num_epochs=3)
# Out:
# Epoch 0, train_loss: 1.24841654
# Epoch 0, valid_accs: 0.60333335
# Epoch 1, train_loss: 0.96706432
# Epoch 1, valid_accs: 0.55333334
# Epoch 2, train_loss: 0.87396657
# Epoch 2, valid_accs: 0.68333334

# %% [markdown]
# Сохранение и загрузка параметров

# %%
# Get all of the current model parameters
sd = model.state_dict()
print(list(sd.keys()))
print()
print("conv1.bias =", sd["conv1.bias"])
# Out:
# ['conv1.weight', 'conv1.bias', 'conv2.weight', 'conv2.bias', 'conv3.weight', 'conv3.bias', 'fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias']
#
# conv1.bias = tensor([ 0.0412,  0.0761, -0.0687, -0.1119,  0.0886, -0.0195])

# %%
# Save the parameters to disk
torch.save(sd, "model.pt")

# %%
# Re-create the model object from scratch
model = MyModel(num_classes=len(CLASSES))

# Load the saved parameters
#
# WARNING!
# By default, torch.load uses pickle which
# can cause arbitrary code execution.
#
# NEVER use torch.load without explicitly setting
# weights_only=True. Alternatively, consider using
# safetensors when loading parameters from
# unknown/untrusted sources.
sd = torch.load(
    "model.pt",
    map_location=DEVICE,
    weights_only=True,
)
model.load_state_dict(sd)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ---

# %% [markdown]
# ## PyTorch Lightning

# %% [markdown]
# <img src="https://code.mipt.ru/courses-public/cv/storage/-/raw/seminars/nn-training-basics/lightning_logo.png" width="50%">

# %% [markdown]
# ### Почему PyTorch Lightning?
#
# #### Много реализованного функционала
#
# * Обучение на GPU/нескольких GPU/TPU
#
# * Multi-node training
#
# * Авто логгирование
#
# * Gradient accumulation
#
# * …
#
# #### Меньше boilerplate кода
#
# Любое исследование можно начать с простого кода и быстро добавить более сложные (уже реализованные) вещи, такие как: обучение на GPU, 16-bit, сохрание чекпоинтов, логгирование, …
#
# PyTorch Lightning сделал и протестировал много всего за Вас, чтобы Вы могли сосредоточиться на исследовании других идей.
#
# Меньше инженерного кода означает:
#
# * меньше багов
#
# * более быстрое итерирование и прототипирование
#
# #### Стандартная структура кода
#
# PyTorch Lightning задает дефолтную "opinionated" схему организации кода. Переходя в новый проект не нужно с нуля разбираться в том, как авторы переизобрели велосипед. Callback функции имеют предсказуемые имена, меньше глобальных объектов, меньше магических констант и тп.

# %%
import lightning as L


# Direct translation of the previous train function
class MyTrainingModule(L.LightningModule):
    def __init__(self):
        super().__init__()
        self.model = MyModel(num_classes=len(CLASSES))
        self.train_loss = []
        self.valid_accs = []

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=1e-3)

    def training_step(self, batch):
        x, y = batch
        p = self.model(x)
        loss = F.cross_entropy(p, y)
        self.train_loss.append(loss.detach())
        return loss

    def validation_step(self, batch):
        x, y = batch
        p = self.model(x)
        matches = p.argmax(axis=-1) == y
        self.valid_accs.append(matches)
        return {}

    def on_train_epoch_end(self):
        epoch_loss = torch.stack(self.train_loss).mean()
        print(
            f"Epoch {self.trainer.current_epoch},",
            f"train_loss: {epoch_loss.item():.8f}",
        )
        # don't forget to clear the saved losses
        self.train_loss.clear()

    def on_validation_epoch_end(self):
        epoch_accs = torch.concat(self.valid_accs).float().mean()
        print(
            f"Epoch {self.trainer.current_epoch},",
            f"valid_accs: {epoch_accs.item():.8f}",
        )
        # don't forget to clear the saved accuracies
        self.valid_accs.clear()

# %%
# Init our training module
training_module = MyTrainingModule()

# Initialize a trainer
trainer = L.Trainer(accelerator="auto", max_epochs=3)

# Train the model ⚡
trainer.fit(training_module, dl_train, dl_valid)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# d:\MIPT\CV\MIPT_ML_CV\venv\Lib\site-packages\lightning\pytorch\trainer\connectors\logger_connector\logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#
#   | Name  | Type    | Params | Mode  | FLOPs
# --------------------------------------------------
# 0 | model | MyModel | 42.2 K | train | 0
# --------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# d:\MIPT\CV\MIPT_ML_CV\venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 30.77it/s] Epoch 0, valid_accs: 1.00000000
# d:\MIPT\CV\MIPT_ML_CV\venv\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 75/75 [00:11<00:00,  6.52it/s, v_num=0]Epoch 0, valid_accs: 0.58333331
# Epoch 0: 100%|██████████| 75/75 [00:13<00:00,  5.41it/s, v_num=0]Epoch 0, train_loss: 1.24840999
# Epoch 1: 100%|██████████| 75/75 [00:10<00:00,  6.89it/s, v_num=0]Epoch 1, valid_accs: 0.64999998
# Epoch 1: 100%|██████████| 75/75 [00:13<00:00,  5.71it/s, v_num=0]Epoch 1, train_loss: 0.93883431
# Epoch 2: 100%|██████████| 75/75 [00:10<00:00,  6.93it/s, v_num=0]Epoch 2, valid_accs: 0.66333336
# Epoch 2: 100%|██████████| 75/75 [00:13<00:00,  5.68it/s, v_num=0]Epoch 2, train_loss: 0.81933320
# `Trainer.fit` stopped: `max_epochs=3` reached.
# Epoch 2: 100%|██████████| 75/75 [00:13<00:00,  5.67it/s, v_num=0]

# %% [markdown]
# ### Возобновление обучения
#
# Как уже было сказано выше в Pytorch Lightning реализовано автоматическое логгирование.
#
# Сохранены все запуски:

# %%
#!tree lightning_logs/
# !ls -R lightning_logs/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Как видите, Lightning автоматически сохранил чекпоинт последней эпохи. Если прервать обучение, то все равно будет сохранены результаты с последней успешно завершившейся эпохи.
#
# Обратите внимание, что чекпоинт - это не просто веса обученной модели. Например, в чекпоинт также включаются статистики оптимизатора. Таким образом, используя чекпоинт можно возобновить прерванный процесс обучения.

# %%
last_ckpt = "lightning_logs/version_0/checkpoints/epoch=2-step=225.ckpt"
ckpt = torch.load(last_ckpt, weights_only=True, map_location=DEVICE)
print(list(ckpt.keys()))
# Out:
# ['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers']

# %%
# Continue training the model for 2 more epochs
training_module = MyTrainingModule()
trainer = L.Trainer(accelerator="auto", max_epochs=5)
trainer.fit(training_module, dl_train, dl_valid, ckpt_path=last_ckpt)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Restoring states from the checkpoint path at lightning_logs/version_0/checkpoints/epoch=2-step=225.ckpt
# d:\MIPT\CV\MIPT_ML_CV\venv\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:566: The dirpath has changed from 'd:\\MIPT\\CV\\MIPT_ML_CV\\04-sem-CNN\\lightning_logs\\version_0\\checkpoints' to 'd:\\MIPT\\CV\\MIPT_ML_CV\\04-sem-CNN\\lightning_logs\\version_1\\checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
#
#   | Name  | Type    | Params | Mode  | FLOPs
# --------------------------------------------------
# 0 | model | MyModel | 42.2 K | train | 0
# --------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Restored all states from the checkpoint at lightning_logs/version_0/checkpoints/epoch=2-step=225.ckpt
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 38.46it/s] Epoch 2, valid_accs: 0.18750000
# Epoch 3: 100%|██████████| 75/75 [00:10<00:00,  6.83it/s, v_num=1]          Epoch 3, valid_accs: 0.69333333
# Epoch 3: 100%|██████████| 75/75 [00:13<00:00,  5.67it/s, v_num=1]Epoch 3, train_loss: 0.76987612
# Epoch 4: 100%|██████████| 75/75 [00:11<00:00,  6.76it/s, v_num=1]Epoch 4, valid_accs: 0.69666666
# Epoch 4: 100%|██████████| 75/75 [00:13<00:00,  5.63it/s, v_num=1]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4, train_loss: 0.71343333
# Epoch 4: 100%|██████████| 75/75 [00:13<00:00,  5.62it/s, v_num=1]

# %% [markdown]
# ### Tensorboard
#
# Инструментарий визуализации от TensorFlow встроенный создателями Pytorch Lightning

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir lightning_logs
# Out:
# Reusing TensorBoard on port 6006 (pid 11808), started 0:24:30 ago. (Use '!kill 11808' to kill it.)
#       <iframe id="tensorboard-frame-fe242d60a301aeb0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-fe242d60a301aeb0");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Подсчет метрик

# %%
import torchmetrics


class MyTrainingModule(L.LightningModule):
    def __init__(self, num_classes=len(CLASSES)):
        super().__init__()
        self.model = MyModel(num_classes=num_classes)
        self.accuracy = torchmetrics.classification.Accuracy(
            task="multiclass",
            num_classes=num_classes,
        )

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=1e-3)

    def training_step(self, batch):
        return self._step(batch, "train")

    def validation_step(self, batch):
        return self._step(batch, "valid")

    def _step(self, batch, kind):
        x, y = batch
        p = self.model(x)
        loss = F.cross_entropy(p, y)
        accs = self.accuracy(p.argmax(axis=-1), y)

        metrics = {
            f"{kind}_accs": accs,
            f"{kind}_loss": loss,
        }
        self.log_dict(
            metrics,
            prog_bar=True,
            logger=True,
            on_step=kind == "train",
            on_epoch=True,
        )

        return loss

# %%
def my_progress_bar():
    return L.pytorch.callbacks.TQDMProgressBar(leave=True)

# %%
training_module = MyTrainingModule()
trainer = L.Trainer(
    accelerator="auto",
    max_epochs=3,
    callbacks=[my_progress_bar()],
    # Make on_step log *literally* every step
    # (since our dataset is so small)
    log_every_n_steps=1,  # for demonstration puproses only
)
trainer.fit(training_module, dl_train, dl_valid)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name     | Type               | Params | Mode  | FLOPs
# ----------------------------------------------------------------
# 0 | model    | MyModel            | 42.2 K | train | 0
# 1 | accuracy | MulticlassAccuracy | 0      | train | 0
# ----------------------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 75/75 [00:13<00:00,  5.44it/s, v_num=2, train_accs_step=0.562, train_loss_step=1.180, valid_accs=0.583, valid_loss=1.010, train_accs_epoch=0.439, train_loss_epoch=1.270]
# Epoch 1: 100%|██████████| 75/75 [00:13<00:00,  5.45it/s, v_num=2, train_accs_step=0.812, train_loss_step=0.557, valid_accs=0.677, valid_loss=0.815, train_accs_epoch=0.634, train_loss_epoch=0.901]
# Epoch 2: 100%|██████████| 75/75 [00:13<00:00,  5.62it/s, v_num=2, train_accs_step=0.750, train_loss_step=0.763, valid_accs=0.630, valid_loss=0.865, train_accs_epoch=0.705, train_loss_epoch=0.769]
# `Trainer.fit` stopped: `max_epochs=3` reached.

# %% [markdown]
# ### Расписание learning rate
#
# При обучении нейронной сети полезно постепенно снижать темп обучения для того, чтобы более точно попасть в локальный минимум.
#
# Снижают learning rate по определенным правилам. Достаточно часто используют один из следующих подходов:
#
# - **time-based decay**
#   $$\alpha(step) = \alpha_0\ {\cdot}\ \frac{1}{1 + \gamma{\cdot}step}$$
#   <br/>
#
# - **smooth exponential decay**
#   $$\alpha(step) = \alpha_0\ {\cdot}\ {\gamma}^{step} \qquad (0 < \gamma < 1)$$
#   <br/>
#
# - **stepwise exponential decay**
#   $$\alpha(step) = \alpha_0\ {\cdot}\ {\gamma}^{\left\lfloor\frac{step}{interval}\right\rfloor} \qquad (\text{e.g. }\ \gamma = 0.1,\ \ interval \propto epoch)$$
#   <br/>
#
# - **plateau decay**
#   $$
#       \alpha(0) = \alpha_0\\
#       \alpha(epoch) = \begin{cases}
#           \alpha(epoch - 1)\ {\cdot}\ \gamma\quad\text{if metrics didn't improving for }P\text{ epochs}\\
#           \alpha(epoch - 1)\quad\quad\text{otherwise}
#       \end{cases}
#   $$
#
# <br/>
# <img src="https://code.mipt.ru/courses-public/cv/storage/-/raw/seminars/nn-training-basics/lr_schedulers.png" width="50%">

# %%
class MyTrainingModule_WithLRScheduler(MyTrainingModule):
    def configure_optimizers(self):
        optimizer = super().configure_optimizers()

        lr_scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer,
            # decay the LR every five epochs
            step_size=5,
            gamma=0.1,
        )

        lr_scheduler_config = {
            "scheduler": lr_scheduler,
            # The unit of the scheduler's step size, could also be 'step'.
            # 'epoch' updates the scheduler on epoch end whereas 'step'
            # updates it after a optimizer update.
            "interval": "epoch",
            # How many epochs/steps should pass between calls to
            # `scheduler.step()`. 1 corresponds to updating the learning
            # rate after every `interval` (epoch or step).
            "frequency": 1,
            ## Metric to to monitor for schedulers like `ReduceLROnPlateau`
            # "monitor": "valid_accs",
        }

        return [optimizer], [lr_scheduler_config]

# %%
def my_lr_monitor():
    return L.pytorch.callbacks.LearningRateMonitor()

# %%
training_module = MyTrainingModule_WithLRScheduler()
trainer = L.Trainer(
    accelerator="auto",
    max_epochs=10,
    callbacks=[my_progress_bar(), my_lr_monitor()],
    log_every_n_steps=1,  # for demonstration puproses only
)
trainer.fit(training_module, dl_train, dl_valid)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name     | Type               | Params | Mode  | FLOPs
# ----------------------------------------------------------------
# 0 | model    | MyModel            | 42.2 K | train | 0
# 1 | accuracy | MulticlassAccuracy | 0      | train | 0
# ----------------------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 75/75 [00:12<00:00,  5.83it/s, v_num=3, train_accs_step=0.438, train_loss_step=1.190, valid_accs=0.607, valid_loss=0.983, train_accs_epoch=0.494, train_loss_epoch=1.230]
# Epoch 1: 100%|██████████| 75/75 [00:12<00:00,  6.00it/s, v_num=3, train_accs_step=0.812, train_loss_step=0.679, valid_accs=0.680, valid_loss=0.868, train_accs_epoch=0.658, train_loss_epoch=0.919]
# Epoch 2: 100%|██████████| 75/75 [00:12<00:00,  5.95it/s, v_num=3, train_accs_step=0.750, train_loss_step=0.828, valid_accs=0.717, valid_loss=0.793, train_accs_epoch=0.674, train_loss_epoch=0.830]
# Epoch 3: 100%|██████████| 75/75 [00:13<00:00,  5.49it/s, v_num=3, train_accs_step=0.625, train_loss_step=0.884, valid_accs=0.737, valid_loss=0.738, train_accs_epoch=0.721, train_loss_epoch=0.736]
# Epoch 4: 100%|██████████| 75/75 [00:14<00:00,  5.25it/s, v_num=3, train_accs_step=0.625, train_loss_step=0.736, valid_accs=0.707, valid_loss=0.770, train_accs_epoch=0.734, train_loss_epoch=0.685]
# Epoch 5: 100%|██████████| 75/75 [00:13<00:00,  5.59it/s, v_num=3, train_accs_step=0.750, train_loss_step=0.633, valid_accs=0.723, valid_loss=0.720, train_accs_epoch=0.771, train_loss_epoch=0.587]
# Epoch 6: 100%|██████████| 75/75 [00:13<00:00,  5.47it/s, v_num=3, train_accs_step=0.875, train_loss_step=0.344, valid_accs=0.733, valid_loss=0.719, train_accs_epoch=0.784, train_loss_epoch=0.553]
# Epoch 7: 100%|██████████| 75/75 [00:13<00:00,  5.49it/s, v_num=3, train_accs_step=0.750, train_loss_step=0.497, valid_accs=0.733, valid_loss=0.722, train_accs_epoch=0.788, train_loss_epoch=0.541]
# Epoch 8: 100%|██████████| 75/75 [00:13<00:00,  5.76it/s, v_num=3, train_accs_step=0.875, train_loss_step=0.444, valid_accs=0.720, valid_loss=0.725, train_accs_epoch=0.789, train_loss_epoch=0.530]
# Epoch 9: 100%|██████████| 75/75 [00:14<00:00,  5.35it/s, v_num=3, train_accs_step=0.938, train_loss_step=0.215, valid_accs=0.713, valid_loss=0.723, train_accs_epoch=0.796, train_loss_epoch=0.521]
# `Trainer.fit` stopped: `max_epochs=10` reached.

# %% [markdown]
# ### Кастомизация чекпоинтов
#
# Мы уже видели, что Pytorch Lightning сохраняет веса модели самостоятельно. Однако сохраняются веса только последней эпохи, метрики на которой могут быть не максимальны, чтобы это исправить самостоятельно напишем callback **`ModelCheckpoint`**.
#
# Также воспользуемся **`EarlyStopping`** для того, чтобы обучение останавливалось при отсутствие роста метрик в течение нескольких эпох.

# %%
def my_training_checkpoint():
    # Save the training module periodically by monitoring a quantity.
    return L.pytorch.callbacks.ModelCheckpoint(
        filename="{epoch}-{valid_accs:.3f}",
        monitor="valid_accs",
        mode="max",
        save_top_k=1,
        save_last=True,
    )


def my_early_stopping():
    # Monitor a metric and stop training when it stops improving.
    return L.pytorch.callbacks.EarlyStopping(
        monitor="valid_accs",
        mode="max",
        patience=4,
        verbose=True,
    )

# %%
training_module = MyTrainingModule_WithLRScheduler()
trainer = L.Trainer(
    max_epochs=100,
    accelerator="auto",
    callbacks=[
        my_progress_bar(),
        my_lr_monitor(),
        my_training_checkpoint(),
        my_early_stopping(),
    ],
    log_every_n_steps=1,  # for demonstration puproses only
)
trainer.fit(training_module, dl_train, dl_valid)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name     | Type               | Params | Mode  | FLOPs
# ----------------------------------------------------------------
# 0 | model    | MyModel            | 42.2 K | train | 0
# 1 | accuracy | MulticlassAccuracy | 0      | train | 0
# ----------------------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 75/75 [00:13<00:00,  5.74it/s, v_num=4, train_accs_step=0.562, train_loss_step=1.740, valid_accs=0.590, valid_loss=0.989, train_accs_epoch=0.444, train_loss_epoch=1.310]
# Metric valid_accs improved. New best score: 0.590
# Epoch 1: 100%|██████████| 75/75 [00:12<00:00,  5.86it/s, v_num=4, train_accs_step=0.625, train_loss_step=0.838, valid_accs=0.683, valid_loss=0.830, train_accs_epoch=0.615, train_loss_epoch=0.937]
# Metric valid_accs improved by 0.093 >= min_delta = 0.0. New best score: 0.683
# Epoch 2: 100%|██████████| 75/75 [00:12<00:00,  5.78it/s, v_num=4, train_accs_step=0.750, train_loss_step=0.633, valid_accs=0.680, valid_loss=0.794, train_accs_epoch=0.669, train_loss_epoch=0.834]
# Epoch 3: 100%|██████████| 75/75 [00:14<00:00,  5.36it/s, v_num=4, train_accs_step=0.625, train_loss_step=0.846, valid_accs=0.687, valid_loss=0.835, train_accs_epoch=0.681, train_loss_epoch=0.768]
# Metric valid_accs improved by 0.003 >= min_delta = 0.0. New best score: 0.687
# Epoch 4: 100%|██████████| 75/75 [00:13<00:00,  5.70it/s, v_num=4, train_accs_step=0.500, train_loss_step=0.937, valid_accs=0.680, valid_loss=0.782, train_accs_epoch=0.722, train_loss_epoch=0.717]
# Epoch 5: 100%|██████████| 75/75 [00:15<00:00,  4.93it/s, v_num=4, train_accs_step=0.812, train_loss_step=0.435, valid_accs=0.720, valid_loss=0.726, train_accs_epoch=0.740, train_loss_epoch=0.638]
# Metric valid_accs improved by 0.033 >= min_delta = 0.0. New best score: 0.720
# Epoch 6: 100%|██████████| 75/75 [00:14<00:00,  5.28it/s, v_num=4, train_accs_step=0.688, train_loss_step=0.688, valid_accs=0.707, valid_loss=0.739, train_accs_epoch=0.752, train_loss_epoch=0.607]
# Epoch 7: 100%|██████████| 75/75 [00:14<00:00,  5.11it/s, v_num=4, train_accs_step=0.750, train_loss_step=0.502, valid_accs=0.713, valid_loss=0.740, train_accs_epoch=0.758, train_loss_epoch=0.601]
# Epoch 8: 100%|██████████| 75/75 [00:15<00:00,  4.75it/s, v_num=4, train_accs_step=0.688, train_loss_step=1.080, valid_accs=0.717, valid_loss=0.721, train_accs_epoch=0.764, train_loss_epoch=0.591]
# Epoch 9: 100%|██████████| 75/75 [00:15<00:00,  4.89it/s, v_num=4, train_accs_step=0.875, train_loss_step=0.628, valid_accs=0.727, valid_loss=0.725, train_accs_epoch=0.763, train_loss_epoch=0.584]
# Metric valid_accs improved by 0.007 >= min_delta = 0.0. New best score: 0.727
# Epoch 10: 100%|██████████| 75/75 [00:14<00:00,  5.18it/s, v_num=4, train_accs_step=0.750, train_loss_step=0.773, valid_accs=0.727, valid_loss=0.713, train_accs_epoch=0.773, train_loss_epoch=0.578]
# Epoch 11: 100%|██████████| 75/75 [00:14<00:00,  5.18it/s, v_num=4, train_accs_step=0.750, train_loss_step=0.578, valid_accs=0.717, valid_loss=0.711, train_accs_epoch=0.774, train_loss_epoch=0.571]
# Epoch 12: 100%|██████████| 75/75 [00:14<00:00,  5.24it/s, v_num=4, train_accs_step=0.688, train_loss_step=0.708, valid_accs=0.720, valid_loss=0.711, train_accs_epoch=0.773, train_loss_epoch=0.568]
# Epoch 13: 100%|██████████| 75/75 [00:15<00:00,  4.93it/s, v_num=4, train_accs_step=0.875, train_loss_step=0.636, valid_accs=0.720, valid_loss=0.711, train_accs_epoch=0.774, train_loss_epoch=0.567]
# Monitored metric valid_accs did not improve in the last 4 records. Best score: 0.727. Signaling Trainer to stop.

# %%
# !tree lightning_logs/
# Out:
# Folder PATH listing for volume WORK
# Volume serial number is 0000002F 20D6:CAB0
# D:\MIPT\CV\MIPT_ML_CV\04-SEM-CNN\LIGHTNING_LOGS
# ����version_0
# �   ����checkpoints
# ����version_1
# �   ����checkpoints
# ����version_2
# �   ����checkpoints
# ����version_3
# �   ����checkpoints
# ����version_4
#     ����checkpoints

# %% [markdown]
# ------

# %% [markdown]
# <img src="https://code.mipt.ru/courses-public/cv/storage/-/raw/seminars/nn-training-basics/albumentations_logo.png" width="50%">

# %% [markdown]
# ## Почему Albumentations?
# Albumentations - это Python библиотека для быстрого и гибкого аугментирования изображений. Albumentations эффективно реализует широкий спектр операций преобразования изображений и обеспечивает при этом лаконичный, но мощный интерфейс для различных задач компьютерного зрения, включая классификацию, сегментацию и детекцию.

# %% [markdown]
# ### Пример аугментаций из Albumentations:

# %% [markdown]
# ![](https://code.mipt.ru/courses-public/cv/storage/-/raw/seminars/nn-training-basics/albumentations_1.png)

# %% [markdown]
# ### Пример использования:

# %%
# %pip install albumentations

# %%
import albumentations as A

# %%
MyTransform = A.Compose(
    [
        A.RandomResizedCrop(size=(128,128),p=0.3),
        A.Rotate(limit=30),
        A.HorizontalFlip(p=0.3),
        A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
    ]
)

# %%
show_images(weather_images, titles)
for _ in range(4):
    transformed = [
        MyTransform(image=np.array(image))["image"]
        for image in weather_images
        #
    ]
    show_images(transformed)

# %%
MyTransform = A.Compose(
    [
        A.SmallestMaxSize(max_size=160),
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
        A.RandomCrop(height=128, width=128),
        A.RGBShift(r_shift_limit=15, g_shift_limit=15, b_shift_limit=15, p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        A.HorizontalFlip(p=0.3),
    ]
)
# Out:
# d:\MIPT\CV\MIPT_ML_CV\venv\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
show_images(weather_images, titles)
for _ in range(4):
    transformed = [
        MyTransform(image=np.array(image))["image"]
        for image in weather_images
        #
    ]
    show_images(transformed)

# %% [markdown]
# #### Ковариантное преобразование изображений и меток

# %% [markdown]
# ![](https://code.mipt.ru/courses-public/cv/storage/-/raw/seminars/nn-training-basics/albumentations_2.png)

# %% [markdown]
# ------

# %% [markdown]
# ### Добавим аугментации в обучение

# %%
import albumentations.pytorch.transforms

augmentations = [
    A.SmallestMaxSize(max_size=160),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
    A.RandomCrop(height=128, width=128),
    A.RGBShift(r_shift_limit=15, g_shift_limit=15, b_shift_limit=15, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
    A.HorizontalFlip(p=0.3),
]
# Don't forget to prepare the image data for consumption by PyTorch
common_transforms = [
    A.Resize(*NETWORK_SIZE),
    A.ToFloat(max_value=255),
    A.Normalize(max_pixel_value=1.0, mean=IMAGENET_MEAN, std=IMAGENET_STD),
    A.pytorch.transforms.ToTensorV2(),
]

MyTrainTransform = A.Compose(augmentations + common_transforms)
MyValidTransform = A.Compose(common_transforms)

# %%
def my_train_transform(image):
    return MyTrainTransform(image=image)["image"]


def my_valid_transform(image):
    return MyValidTransform(image=image)["image"]


ds_train_alb = MyCustomDataset(
    mode="train",
    transform=my_train_transform,
)
ds_valid_alb = MyCustomDataset(
    mode="valid",
    transform=my_valid_transform,
)

dl_train_alb = data.DataLoader(
    ds_train_alb,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    num_workers=0,
)
dl_valid_alb = data.DataLoader(
    ds_valid_alb,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    num_workers=0,
)

# %%
training_module = MyTrainingModule_WithLRScheduler()
trainer = L.Trainer(
    max_epochs=100,
    accelerator="auto",
    callbacks=[
        my_progress_bar(),
        my_lr_monitor(),
        my_training_checkpoint(),
        my_early_stopping(),
    ],
    log_every_n_steps=1,  # for demonstration puproses only
)
trainer.fit(training_module, dl_train_alb, dl_valid_alb)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name     | Type               | Params | Mode  | FLOPs
# ----------------------------------------------------------------
# 0 | model    | MyModel            | 42.2 K | train | 0
# 1 | accuracy | MulticlassAccuracy | 0      | train | 0
# ----------------------------------------------------------------
# 42.2 K    Trainable params
# 0         Non-trainable params
# 42.2 K    Total params
# 0.169     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 75/75 [00:09<00:00,  7.67it/s, v_num=5, train_accs_step=0.562, train_loss_step=0.999, valid_accs=0.520, valid_loss=1.180, train_accs_epoch=0.403, train_loss_epoch=1.370]
# Metric valid_accs improved. New best score: 0.520
# Epoch 1: 100%|██████████| 75/75 [00:09<00:00,  7.60it/s, v_num=5, train_accs_step=0.750, train_loss_step=0.824, valid_accs=0.650, valid_loss=0.936, train_accs_epoch=0.542, train_loss_epoch=1.110]
# Metric valid_accs improved by 0.130 >= min_delta = 0.0. New best score: 0.650
# Epoch 2: 100%|██████████| 75/75 [00:10<00:00,  7.10it/s, v_num=5, train_accs_step=0.562, train_loss_step=1.120, valid_accs=0.710, valid_loss=0.803, train_accs_epoch=0.582, train_loss_epoch=0.995]
# Metric valid_accs improved by 0.060 >= min_delta = 0.0. New best score: 0.710
# Epoch 3: 100%|██████████| 75/75 [00:11<00:00,  6.44it/s, v_num=5, train_accs_step=0.562, train_loss_step=1.010, valid_accs=0.667, valid_loss=0.812, train_accs_epoch=0.610, train_loss_epoch=0.975]
# Epoch 4: 100%|██████████| 75/75 [00:10<00:00,  6.91it/s, v_num=5, train_accs_step=0.688, train_loss_step=0.747, valid_accs=0.700, valid_loss=0.756, train_accs_epoch=0.632, train_loss_epoch=0.885]
# Epoch 5: 100%|██████████| 75/75 [00:10<00:00,  6.97it/s, v_num=5, train_accs_step=0.625, train_loss_step=0.890, valid_accs=0.700, valid_loss=0.740, train_accs_epoch=0.657, train_loss_epoch=0.846]
# Epoch 6: 100%|██████████| 75/75 [00:11<00:00,  6.63it/s, v_num=5, train_accs_step=0.562, train_loss_step=1.250, valid_accs=0.693, valid_loss=0.731, train_accs_epoch=0.678, train_loss_epoch=0.812]
# Monitored metric valid_accs did not improve in the last 4 records. Best score: 0.710. Signaling Trainer to stop.

# %% [markdown]
# ---
